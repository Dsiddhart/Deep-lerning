# %% [markdown]
# <a href="https://colab.research.google.com/github/Dsiddhart/Deep-lerning/blob/main/Pyhton_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list is ordered, mutable, allows duplicate elements
mylist=["sss","ffff","aad"]
print(mylist)
# Out:
# ['sss', 'ffff', 'aad']

# %%
mylist2=list()
print(mylist2)
# Out:
# []

# %%
mylist2=[5,True,"a","a"]

# %%
print(mylist2)
# Out:
# [5, True, 'a', 'a']

# %%
item=mylist2[2
             ]
print(item)
# Out:
# a

# %%
item=mylist2[-2]

print(item)
# Out:
# a

# %%
for i in mylist:
  print(i)
# Out:
# sss
# ffff
# aad

# %%
if "sss"in mylist:
  print("yes")

else:
  print("no")
# Out:
# yes

# %%
len(mylist)
# Out:
# 3

# %%
mylist.append("hhh")
print(mylist)
# Out:
# ['sss', 'ffff', 'aad', 'hhh']

# %%
mylist.insert(1,"llkl")
print(mylist)
# Out:
# ['sss', 'llkl', 'ffff', 'aad', 'hhh']

# %%
item=mylist.pop()
print(item)
print(mylist)
# Out:
# hhh
# ['sss', 'llkl', 'ffff', 'aad']

# %%
mylist.remove("sss")
print(mylist)
mylist.clear()
print(mylist)
len(mylist)
# Out:
# ['llkl', 'ffff', 'aad']
# []
# 0

# %%
print(mylist2)
print(mylist2.reverse())
# Out:
# [5, True, 'a', 'a']
# None

# %% [markdown]
# Let's demonstrate that `mylist2.reverse()` modifies the list in-place and returns `None`.

# %%
print(f"Original mylist2: {mylist2}")
return_value = mylist2.reverse()
print(f"Return value of reverse(): {return_value}")
print(f"mylist2 after reverse(): {mylist2}")
# Out:
# Original mylist2: ['a', 'a', True, 5]
# Return value of reverse(): None
# mylist2 after reverse(): [5, True, 'a', 'a']

# %%
print(mylist2)
print(mylist2.remove("a"))
# Out:
# [5, True, 'a', 'a']
# None

# %%
mylist2.append(5)

# %%
print(mylist2)
item=mylist2.remove(5)
print(item)
print(mylist2)
# Out:
# [True, 5]
# None
# [True]

# %%
item=mylist2.pop()
print(item)
print(mylist2)
# Out:
# True
# []

# %%
mylist=[4,5,3,2,"asdas","asdasd",3,3,True]
print(mylist)
# Out:
# [4, 5, 3, 2, 'asdas', 'asdasd', 3, 3, True]

# %%
mylist=[3,2]
print(mylist)
# Out:
# [3, 2]

# %%
print(mylist)
# Out:
# [4, 5, 3, 2, 'asdas', 'asdasd', 3, 3, True]

# %%
mylist.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3082/1920586842.py in <cell line: 0>()
# ----> 1 mylist.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
listi=[12,-2,55]
print(listi)
new_list=sorted(listi)
print(listi)
print(new_list)
# Out:
# [12, -2, 55]
# [12, -2, 55]
# [-2, 12, 55]

# %%
nlist=[0]*5
print(nlist)
# Out:
# [0, 0, 0, 0, 0]

# %%
nnlist=nlist+listi
print(nnlist)
# Out:
# [0, 0, 0, 0, 0, 12, -2, 55]

# %%
nnlist.sort()
print(nnlist)
# Out:
# [-2, 0, 0, 0, 0, 0, 12, 55]

# %%
a= nnlist[1:5]
print(a)
# Out:
# [0, 0, 0, 0]

# %%
a= nnlist[:5]
print(a)
# Out:
# [-2, 0, 0, 0, 0]

# %%
a= nnlist[2:]
print(a)
# Out:
# [0, 0, 0, 0, 12, 55]

# %%
a=nnlist[0::1]
print(a)
# Out:
# [-2, 0, 0, 0, 0, 0, 12, 55]

# %%
a=nnlist[2::2]
print(a)
# Out:
# [0, 0, 12]

# %%
list_org=["aaa","bbb","ccc"]
list_copy=list_org
list_copy.append("ddd")
print(list_copy)
print(list_org)
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']
# ['aaa', 'bbb', 'ccc', 'ddd']

# %%
list_org=["aaa","bbb","ccc"]
list_copy=list_org.copy()
list_copy.append("ddd")
print(list_copy)
print(list_org)
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']
# ['aaa', 'bbb', 'ccc']

# %%
list_org=["aaa","bbb","ccc"]
list_copy=list(list_org)
list_copy.append("ddd")
print(list_copy)
print(list_org)
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']
# ['aaa', 'bbb', 'ccc']

# %%
list_org=["aaa","bbb","ccc"]
list_copy=list_org[:]
list_copy.append("ddd")
print(list_copy)
print(list_org)
# Out:
# ['aaa', 'bbb', 'ccc', 'ddd']
# ['aaa', 'bbb', 'ccc']

# %%
v=[1,2,3,4,5,6]
b=[i*i for i in v]
print(v)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 4, 9, 16, 25, 36]
