# %% [markdown]
# <a href="https://colab.research.google.com/github/Dsiddhart/Deep-lerning/blob/main/Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set: unordered,mutable,no duplications
s={1,2,3,3,2}
print(s)
# Out:
# {1, 2, 3}

# %%
s= set("Hello")
print(s)
# Out:
# {'o', 'l', 'H', 'e'}

# %%
ss={}
sss=set()
print(type(ss))
print(type(sss))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
sss.add(1)

# %%
sss.add(1)
sss.add(2)

# %%
print(sss)
# Out:
# {1, 2}

# %%
print(sss.pop())
print(sss)
# Out:
# 1
# {2}

# %%
ss={1,2,3,4,5,6,"helll"}
print(ss)
# Out:
# {1, 2, 3, 4, 5, 6, 'helll'}

# %%
for i in ss:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# helll

# %%
odds={1,3,5,7,9}
evens={2,4,6,8}
primes={2,3,5,7}
u=odds.union(evens)
print(u)
v=u.intersection(primes)
print(v)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {2, 3, 5, 7}

# %%
sa={1,2,3,4,5,6,7,8,9}
sb={1,2,3,10,12,11}
diff=sa.difference(sb)
print(diff)
diif=sb.difference(sa)
print(diif)
d=sa.symmetric_difference(sb)
print(d)
# sa.update(sb)
# print(sa)
# sa.intersection_update(sb)
# print(sa)
# sa.difference_update(sb)
# print(sa)
sa.symmetric_difference_update(sb)
print(sa)
# Out:
# {4, 5, 6, 7, 8, 9}
# {10, 11, 12}
# {4, 5, 6, 7, 8, 9, 10, 11, 12}
# {4, 5, 6, 7, 8, 9, 10, 11, 12}

# %%
sa={1,2,3,4,5,6,9}
sb={1,2,3}
sc={44}
print(sa.issubset(sb))
print(sa.issuperset(sb))

print(sb.issubset(sa))
print(sb.issuperset(sa))

print(sa.isdisjoint(sc))
# Out:
# False
# True
# True
# False
# True

# %%
a=frozenset([1,2,3,4])

a.remove(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4102/48196285.py in <cell line: 0>()
#       1 a=frozenset([1,2,3,4])
#       2
# ----> 3 a.remove(1)
#
# AttributeError: 'frozenset' object has no attribute 'remove'
